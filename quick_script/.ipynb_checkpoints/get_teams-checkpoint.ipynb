# %%
from urllib import request, parse
import numpy as np
import requests
import json
from bs4 import BeautifulSoup

with requests.Session() as s:
    url = "https://corner-stats.com/index.php?route=module/team/getTeams"
    
    headers = {
        "Accept": "application/json, text/javascript, */*; q=0.01",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
        "Connection": "keep-alive",
        "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
        "Cookie": "mysessionname=0971v8l2pp0c7opo7ffjq223k1; _ga=GA1.2.571054001.1565702820; __zlcmid=tliSVTIv8Nthfj; language=en; free_access=2; token=327482f52f26b36632b312d347856527; currency=EUR; _gid=GA1.2.1871471604.1579098783",
        "Host": "corner-stats.com",
        "Origin": "https://corner-stats.com",
        "Referer": "https://corner-stats.com/liverpool/england/team/18",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin",
        "X-Requested-With": "XMLHttpRequest",
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36",
    }

    data = {
        'tournament_id': 1
    }

# %%
    req = s.post(url, headers=headers, data=data)

# %%
    teams = req.json()['teams']
    
    teams_dict = {}

    for x in teams:
        teams_dict[x['team_id']] = x['name']

    for x in teams_dict:
        print(teams_dict[x])

    print(len(teams_dict))
# Out:
# Newcastle United
# Sheffield United FC
# Aston Villa
# Paro FC
# West Ham United
# Arsenal
# Brighton & Hove Albion FC
# Manchester United
# Wolverhampton Wanderers FC
# Liverpool
# Crystal Palace FC
# Manchester City
# Southampton
# Chelsea
# Watford FC
# Everton
# Burnley FC
# Leicester City FC
# Norwich City
# AFC Bournemouth
# Tottenham Hotspur
# 21

# %%
    # # Load the JSON to a Python list & dump it back out as formatted JSON
    format_teams = json.dumps(req.json(), indent=4, sort_keys=True)
    print(format_teams)
# Out:
# {
#     "teams": [
#         {
#             "address": "           Dean Court, Kings Park<br />           BH7 7AF<br />           Bournemouth, Dorset       ",
#             "aeroport_code": "",
#             "alias": "/bournemouth/england/team/1682",
#             "alt_name": "Bournemouth",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/afc-bournemouth/711/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/711.png",
#             "name": "AFC Bournemouth",
#             "name_ru": "\u0411\u043e\u0440\u043d\u043c\u0443\u0442",
#             "old_team_id": "0",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "22",
#             "stadium": "",
#             "team_id": "1682",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Championship, England",
#             "weather": "",
#             "year": "1899"
#         },
#         {
#             "address": "           Highbury House, 75 Drayton Park<br />           N5 1BU<br />           London       ",
#             "aeroport_code": "",
#             "alias": "/arsenal/england/team/8",
#             "alt_name": "Arsenal",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/arsenal-fc/660/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/660.png",
#             "name": "Arsenal",
#             "name_ru": "\u0410\u0440\u0441\u0435\u043d\u0430\u043b",
#             "old_team_id": "134",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "Emirates Stadium",
#             "team_id": "8",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "london-18114; 98587/",
#             "year": "1886"
#         },
#         {
#             "address": "           Trinity Road<br />           B6 6HE<br />           Birmingham       ",
#             "aeroport_code": "",
#             "alias": "/aston-villa/england/team/17",
#             "alt_name": "Aston Villa",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/aston-villa-football-club/665/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/665.png",
#             "name": "Aston Villa",
#             "name_ru": "\u0410\u0441\u0442\u043e\u043d \u0412\u0438\u043b\u043b\u0430",
#             "old_team_id": "124",
#             "power_group": "2",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "Villa Park",
#             "team_id": "17",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "birmingham-18532; 82827",
#             "year": "1874"
#         },
#         {
#             "address": "           Village Way<br />           BN1 9BL<br />           Brighton, East Sussex       ",
#             "aeroport_code": "",
#             "alias": "/brighton/england/team/1499",
#             "alt_name": "Brighton",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/brighton--hove-albion-fc/703/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/703.png",
#             "name": "Brighton & Hove Albion FC",
#             "name_ru": "\u0411\u0440\u0430\u0439\u0442\u043e\u043d \u044d\u043d\u0434 \u0425\u0430\u0432 \u0410\u043b\u044c\u0431\u0438\u043e\u043d",
#             "old_team_id": "0",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "",
#             "team_id": "1499",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Championship, England",
#             "weather": "",
#             "year": "1901"
#         },
#         {
#             "address": "           Harry Potts Way<br />           BB10 4BX<br />           Burnley, Lancashire       ",
#             "aeroport_code": "",
#             "alias": "/burnley/england/team/1629",
#             "alt_name": "Burnley",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/burnley-fc/698/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/698.png",
#             "name": "Burnley FC",
#             "name_ru": "\u0411\u0435\u0440\u043d\u043b\u0438",
#             "old_team_id": "0",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "19",
#             "stadium": "",
#             "team_id": "1629",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "",
#             "year": "1882"
#         },
#         {
#             "address": "           Fulham Road<br />           SW6 1HS<br />           London       ",
#             "aeroport_code": "",
#             "alias": "/chelsea/england/team/1",
#             "alt_name": "Chelsea",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/chelsea-football-club/661/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/661.png",
#             "name": "Chelsea",
#             "name_ru": "\u0427\u0435\u043b\u0441\u0438",
#             "old_team_id": "129",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "Stamford Bridge",
#             "team_id": "1",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "london-18114; 98587",
#             "year": "1905"
#         },
#         {
#             "address": "           Selhurst Park<br />           SE25 6PU<br />           London       ",
#             "aeroport_code": "",
#             "alias": "/crystal-palace/england/team/1485",
#             "alt_name": "Crystal Palace",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/crystal-palace-fc/679/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/679.png",
#             "name": "Crystal Palace FC",
#             "name_ru": "\u041a\u0440\u0438\u0441\u0442\u0430\u043b \u041f\u044d\u043b\u044d\u0441",
#             "old_team_id": "0",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "21",
#             "stadium": "",
#             "team_id": "1485",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "",
#             "year": "1905"
#         },
#         {
#             "address": "           Goodison Road<br />           L4 4EL<br />           Liverpool       ",
#             "aeroport_code": "",
#             "alias": "/everton/england/team/6",
#             "alt_name": "Everton",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/everton-football-club/674/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/674.png",
#             "name": "Everton",
#             "name_ru": "\u042d\u0432\u0435\u0440\u0442\u043e\u043d",
#             "old_team_id": "128",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "Goodison Park",
#             "team_id": "6",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "liverpool-2872; 33428",
#             "year": "1878"
#         },
#         {
#             "address": "           Filbert Way<br />           LE2 7FL<br />           Leicester       ",
#             "aeroport_code": "",
#             "alias": "/leicester/england/team/1490",
#             "alt_name": "Leicester",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/leicester-city-fc/682/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/682.png",
#             "name": "Leicester City FC",
#             "name_ru": "\u041b\u0435\u0441\u0442\u0435\u0440 \u0421\u0438\u0442\u0438",
#             "old_team_id": "0",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "30",
#             "stadium": "",
#             "team_id": "1490",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "",
#             "year": "1884"
#         },
#         {
#             "address": "           Anfield Road<br />           L4 0TH<br />           Liverpool       ",
#             "aeroport_code": "",
#             "alias": "/liverpool/england/team/18",
#             "alt_name": "Liverpool",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/liverpool-fc/663/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/663.png",
#             "name": "Liverpool",
#             "name_ru": "\u041b\u0438\u0432\u0435\u0440\u043f\u0443\u043b\u044c",
#             "old_team_id": "140",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "Anfield",
#             "team_id": "18",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "liverpool-2872; 89194",
#             "year": "1892"
#         },
#         {
#             "address": "           Rowsley Street<br />           M11 3FF<br />           Manchester       ",
#             "aeroport_code": "",
#             "alias": "/man-city/england/team/4",
#             "alt_name": "Man City",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/manchester-city-football-club/676/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/676.png",
#             "name": "Manchester City",
#             "name_ru": "\u041c\u0430\u043d\u0447\u0435\u0441\u0442\u0435\u0440 \u0421\u0438\u0442\u0438",
#             "old_team_id": "131",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "28",
#             "stadium": "Etihad Stadium",
#             "team_id": "4",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "manchester-18366; 27475",
#             "year": "1880"
#         },
#         {
#             "address": "           Sir Matt Busby Way<br />           M16 0RA<br />           Manchester       ",
#             "aeroport_code": "",
#             "alias": "/man-utd/england/team/5",
#             "alt_name": "Man Utd",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/manchester-united-fc/662/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/662.png",
#             "name": "Manchester United",
#             "name_ru": "\u041c\u0430\u043d\u0447\u0435\u0441\u0442\u0435\u0440 \u042e\u043d.",
#             "old_team_id": "122",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "27",
#             "stadium": "Old Trafford",
#             "team_id": "5",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "manchester-18366; 27475",
#             "year": "1878"
#         },
#         {
#             "address": "           St. James' Park<br />           NE1 4ST<br />           Newcastle-upon-Tyne       ",
#             "aeroport_code": "",
#             "alias": "/newcastle/england/team/10",
#             "alt_name": "Newcastle",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/newcastle-united-football-club/664/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/664.png",
#             "name": "Newcastle United",
#             "name_ru": "\u041d\u044c\u044e\u043a\u0430\u0441\u043b \u042e\u043d.",
#             "old_team_id": "123",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "St. James' Park",
#             "team_id": "10",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "newcastle-upon-tyne-6814; 35693",
#             "year": "1881"
#         },
#         {
#             "address": "           Carrow Road<br />           NR1 1JE<br />           Norwich, Norfolk       ",
#             "aeroport_code": "",
#             "alias": "/norwich/england/team/15",
#             "alt_name": "Norwich",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/norwich-city-fc/677/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/677.png",
#             "name": "Norwich City",
#             "name_ru": "\u041d\u043e\u0440\u0432\u0438\u0447 \u0421\u0438\u0442\u0438",
#             "old_team_id": "201",
#             "power_group": "2",
#             "rate": "0",
#             "rs_team_id": "121",
#             "stadium": "Carrow Road",
#             "team_id": "15",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Championship, England",
#             "weather": "norwich-18641; 46347",
#             "year": "1902"
#         },
#         {
#             "address": "Bhutan",
#             "aeroport_code": "",
#             "alias": "/paro/bhutan/team/8489",
#             "alt_name": "",
#             "country_id": "200",
#             "date_added": "2020-01-16 05:37:23",
#             "is_primary": "0",
#             "link": "/teams/bhutan/paro/47456/",
#             "logo": "https://secure.cache.images.core.optasports.com/soccer/teams/150x150/47456.png",
#             "name": "Paro FC",
#             "name_ru": "",
#             "old_team_id": "0",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "",
#             "team_id": "8489",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, Bhutan",
#             "weather": "",
#             "year": "0"
#         },
#         {
#             "address": "           Bramall Lane<br />           S2 4SU<br />           Sheffield       ",
#             "aeroport_code": "",
#             "alias": "/sheff-utd/england/team/1718",
#             "alt_name": "Sheff Utd",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/sheffield-united-fc/687/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/687.png",
#             "name": "Sheffield United FC",
#             "name_ru": "\u0428\u0435\u0444\u0444\u0438\u043b\u0434 \u042e\u043d.",
#             "old_team_id": "0",
#             "power_group": "2",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "",
#             "team_id": "1718",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "League One, England",
#             "weather": "",
#             "year": "1889"
#         },
#         {
#             "address": "           Britannia Road<br />           S014 5FP<br />           Southampton, Hampshire       ",
#             "aeroport_code": "",
#             "alias": "/southampton/england/team/20",
#             "alt_name": "Southampton",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/southampton-fc/670/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/670.png",
#             "name": "Southampton",
#             "name_ru": "\u0421\u0430\u0443\u0442\u0433\u0435\u043c\u043f\u0442\u043e\u043d",
#             "old_team_id": "189",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "St. Mary's Stadium",
#             "team_id": "20",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "southampton-6425; 12084",
#             "year": "1885"
#         },
#         {
#             "address": "           Bill Nicholson Way, 748 High Road<br />           N17 OAP<br />           Tottenham       ",
#             "aeroport_code": "",
#             "alias": "/tottenham/england/team/14",
#             "alt_name": "Tottenham",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/tottenham-hotspur-football-club/675/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/675.png",
#             "name": "Tottenham Hotspur",
#             "name_ru": "\u0422\u043e\u0442\u0442\u0435\u043d\u0445\u044d\u043c \u0425\u043e\u0442\u0441\u043f\u0443\u0440",
#             "old_team_id": "141",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "White Hart Lane",
#             "team_id": "14",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "tottenham-w514194; 73452",
#             "year": "1882"
#         },
#         {
#             "address": "           Vicarage Road<br />           WD18 0ER<br />           Watford       ",
#             "aeroport_code": "",
#             "alias": "/watford/england/team/1498",
#             "alt_name": "Watford",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/watford-football-club/696/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/696.png",
#             "name": "Watford FC",
#             "name_ru": "\u0423\u043e\u0442\u0444\u043e\u0440\u0434",
#             "old_team_id": "0",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "",
#             "team_id": "1498",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Championship, England",
#             "weather": "",
#             "year": "1881"
#         },
#         {
#             "address": "           Green Street<br />           E13 9AZ<br />           London       ",
#             "aeroport_code": "",
#             "alias": "/west-ham/england/team/7",
#             "alt_name": "West Ham",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/west-ham-united-fc/684/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/684.png",
#             "name": "West Ham United",
#             "name_ru": "\u0412\u0435\u0441\u0442 \u0425\u044d\u043c \u042e\u043d.",
#             "old_team_id": "133",
#             "power_group": "0",
#             "rate": "0",
#             "rs_team_id": "0",
#             "stadium": "Boleyn Ground",
#             "team_id": "7",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Premier League, England",
#             "weather": "london-18114; 98587",
#             "year": "1895"
#         },
#         {
#             "address": "           Waterloo Road<br />           WV1 4QR<br />           Wolverhampton       ",
#             "aeroport_code": "",
#             "alias": "/wolverhampton/england/team/1903",
#             "alt_name": "Wolverhampton",
#             "country_id": "1",
#             "date_added": "0000-00-00 00:00:00",
#             "is_primary": "1",
#             "link": "/teams/england/wolverhampton-wanderers-fc/680/",
#             "logo": "http://cache.images.globalsportsmedia.com/soccer/teams/150x150/680.png",
#             "name": "Wolverhampton Wanderers FC",
#             "name_ru": "\u0412\u0443\u043b\u0432\u0435\u0440\u0433\u0435\u043c\u043f\u0442\u043e\u043d",
#             "old_team_id": "0",
#             "power_group": "1",
#             "rate": "0",
#             "rs_team_id": "131",
#             "stadium": "",
#             "team_id": "1903",
#             "tournament_id": "1",
#             "tournament_name": "Premier League",
#             "tournament_row": "Championship, England",
#             "weather": "",
#             "year": "1877"
#         }
#     ]
# }
