# %%
from urllib import request, parse
import numpy as np
import requests
import json
from bs4 import BeautifulSoup

# %%
with requests.Session() as s:
    url = "https://corner-stats.com/index.php?route=module/getmatches/getTeamsAjax&event_type=corners"
    
    headers = {
        "Accept": "application/json, text/javascript, */*; q=0.01",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
        "Connection": "keep-alive",
        "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
        "Cookie": "mysessionname=0971v8l2pp0c7opo7ffjq223k1; _ga=GA1.2.571054001.1565702820; __zlcmid=tliSVTIv8Nthfj; language=en; free_access=2; token=327482f52f26b36632b312d347856527; currency=EUR; _gid=GA1.2.1871471604.1579098783",
        "Host": "corner-stats.com",
        "Origin": "https://corner-stats.com",
        "Referer": "https://corner-stats.com/liverpool-man-utd-19-01-2020/premier-league-england/match/289053",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin",
        "X-Requested-With": "XMLHttpRequest",
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36",
    }

    data = {
        'tour[]': 1,
        'seasons[]': [24, 40],
        'm_type[]': [1, 2],
        'show': 60,
        'team_id': 18,
        'parameter': 'a:6:{s:8:"table_id";s:19:"table_corners_team1";s:19:"filter_last_matches";i:1;s:11:"filter_team";s:2:"18";s:5:"start";i:0;s:5:"limit";i:20;s:10:"is_filters";i:1;}',
        'event_type': 'filter',
        'event_value': 0
        
#         'place[away]': 1,
#         'date_start_day': '',
#         'date_start_month': '',
#         'date_start_year': '',
#         'date_end_day': '',
#         'date_end_month': '',
#         'date_end_year': '',
#         'show_select': '',
#         'show_input': '',
#         'game_week': ''
    }
    
    encoded_data = "tour%5B%5D=1&seasons%5B%5D=40&m_type%5B%5D=1&m_type%5B%5D=2&show=40&team_id=18&parameter=a%3A6%3A%7Bs%3A8%3A%22table_id%22%3Bs%3A19%3A%22table_corners_team1%22%3Bs%3A19%3A%22filter_last_matches%22%3Bi%3A1%3Bs%3A11%3A%22filter_team%22%3Bs%3A2%3A%2218%22%3Bs%3A5%3A%22start%22%3Bi%3A0%3Bs%3A5%3A%22limit%22%3Bi%3A20%3Bs%3A10%3A%22is_filters%22%3Bi%3A1%3B%7D&event_type=filter&event_value=0"

# %%
    print(data)
# Out:
# {'event_type': 'filter', 'show': 60, 'event_value': 0, 'parameter': 'a:6:{s:8:"table_id";s:19:"table_corners_team1";s:19:"filter_last_matches";i:1;s:11:"filter_team";s:2:"18";s:5:"start";i:0;s:5:"limit";i:20;s:10:"is_filters";i:1;}', 'tour[]': 1, 'm_type[]': [1, 2], 'seasons[]': [24, 40], 'team_id': 18}

# %%
    print(headers)
# Out:
# {'Origin': 'https://corner-stats.com', 'Accept': 'application/json, text/javascript, */*; q=0.01', 'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8', 'Accept-Encoding': 'gzip, deflate, br', 'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36', 'Referer': 'https://corner-stats.com/liverpool-man-utd-19-01-2020/premier-league-england/match/289053', 'Cookie': 'mysessionname=0971v8l2pp0c7opo7ffjq223k1; _ga=GA1.2.571054001.1565702820; __zlcmid=tliSVTIv8Nthfj; language=en; free_access=2; token=327482f52f26b36632b312d347856527; currency=EUR; _gid=GA1.2.1871471604.1579098783', 'Accept-Language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7', 'X-Requested-With': 'XMLHttpRequest', 'Content-Length': '387', 'Host': 'corner-stats.com', 'Sec-Fetch-Site': 'same-origin', 'Sec-Fetch-Mode': 'cors', 'Connection': 'keep-alive'}

# %%
    req = s.post(url, headers=headers, data=data)

# %%
    print(req.content)
# Out:
# b'{"0":{"game_id":"287380","team":-1,"game_id_2":"18","team_1_id":"7","team_name1":"West Ham","team_name2":"Liverpool","team_1_tournament_row":"Premier League, England","team_2_tournament_row":"Premier League, England","team_1_goals_quantity":"?","team_2_goals_quantity":"?","team_1_corners_quantity":"?","team_2_corners_quantity":"?","team_1_yellow_cards":"?","team_2_yellow_cards":"?","team_1_red_cards":"?","team_2_red_cards":"?","other_t1":"","other_t2":"","ft":"#FFE6B2","odds_1":"","odds_x":"","odds_2":"","fora1":"","team_1_href":"\\/west-ham\\/england\\/team\\/7","team_2_href":"\\/liverpool\\/england\\/team\\/18","game_href":"\\/west-ham-liverpool-20-12-2019\\/premier-league-england\\/match\\/287380","tournament_href":"index.php?route=football\\/tournament&amp;tournament_id=1","date_start":"31\\/03\\/20","date_start_timestamp":1585695600000,"tournament_name":"PremL","tournament_href1":"\\/premier-league\\/england\\/tournament\\/1","round_name":"18","referee_name":"","referee_href":
# ...

# %%
matches = req.json()

matches.pop('statistics', None)

matches_dict = {}

for x in matches:
# for x in matches_json:
#     print(matches[x])
    matches_dict[matches[x]['team_name1']] = 1
    matches_dict[matches[x]['team_name2']] = 1
#     print(matches[x]['team_1_id'], ":", matches[x]['team_name1'])

for x in matches_dict:
    print(x)

print(len(matches_dict))
# Out:
# Burnley
# Leicester
# Aston Villa
# Norwich
# Newcastle
# West Ham
# Crystal Palace
# Man City
# Watford
# Southampton
# Wolverhampton
# Everton
# Arsenal
# Liverpool
# Man Utd
# Sheff Utd
# Bournemouth
# Brighton
# Chelsea
# Tottenham
# 20

# %%
# # Load the JSON to a Python list & dump it back out as formatted JSON
format_match = json.dumps(req.json(), indent=4, sort_keys=True)
print(format_match)
# Out:
# {
#     "0": {
#         "corner_count": "0",
#         "date_start": "31/03/20",
#         "date_start_timestamp": 1585695600000,
#         "first_goal": 0,
#         "fora1": "",
#         "ft": "#FFE6B2",
#         "game_href": "/west-ham-liverpool-20-12-2019/premier-league-england/match/287380",
#         "game_id": "287380",
#         "game_id_2": "18",
#         "int_seconds": -1,
#         "odds_1": "",
#         "odds_2": "",
#         "odds_x": "",
#         "other_t1": "",
#         "other_t2": "",
#         "penalty": null,
#         "referee_href": "",
#         "referee_name": "",
#         "round_name": "18",
#         "team": -1,
#         "team_1_corners_quantity": "?",
#         "team_1_goals_1_half": "-1",
#         "team_1_goals_quantity": "?",
#         "team_1_href": "/west-ham/england/team/7",
#         "team_1_id": "7",
#         "team_1_red_cards": "?",
#         "team_1_tournament_row": "Premier League, England",
#         "team_1_yellow_cards": "?",
# ...
